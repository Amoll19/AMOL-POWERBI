# %% [markdown]
# <a href="https://colab.research.google.com/github/Amoll19/AMOL-POWERBI/blob/main/stock_trend_predection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt
stock = 'POWERGRID.NS'
start = dt.datetime(2000,1,1)
end=dt.datetime(2024,11,1)
df=yf.download(stock, start, end)

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df =df.reset_index()

# %%
df.shape

# %%
df.columns

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()

# %%
#candlesticks
import plotly.graph_objects as go


fig = go.Figure(data=[go.Candlestick(x=data01['Date'],open = data01['Open'],
                                     high=data01['High'],
                                     low=data01['Low'],
                                     close=data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
df = df.drop(columns=[('Date', '')])

# %%
df.head()

# %%
plt.figure(figsize =(12,6))
plt.plot(data['C'])
